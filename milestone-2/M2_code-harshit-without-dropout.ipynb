# %% [markdown]
# # MILESTONE 2
#
# IMDB dataset + Siraj's Network

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Preprocessing Dataset
#
# 1. Removing punctuations
# 2. Generating word_to_int map
# 3. Coverting each review in ints
# 4. Padding each review with 0's and generating input of length 200

# %%
import re
from collections import Counter
from nltk.corpus import stopwords

def preprocess(text):
    
    # Replace punctuation with tokens so we can use them in our model
    '''
    text = text.lower()
    text = text.replace('.', ' <PERIOD> ')
    text = text.replace(',', ' <PERIOD> ')
    text = text.replace('"', ' <PERIOD> ')
    text = text.replace(';', ' <PERIOD> ')
    text = text.replace('!', ' <PERIOD> ')
    text = text.replace('?', ' <PERIOD> ')
    text = text.replace('(', ' <PERIOD> ')
    text = text.replace(')', ' <PERIOD> ')
    text = text.replace('--', ' <PERIOD> ')
    text = text.replace('?', ' <PERIOD> ')
    '''
    text = text.replace('<br />', ' <PERIOD> ')
    text = text.replace('\\', ' <PERIOD> ')
    text = text.replace('\n', ' <NEW_LINE> ')
    text = text.replace(':', ' <PERIOD> ')
    text = text.replace(' <PERIOD> ', ' ')
    words = text.split()
    
    return words

def removing_noise(words):
    word_count = Counter(words)
    #stops = set(stopwords.words("english"))
    words_new = [word for word in words if (word_count[word]>5) #and (not word in stops)
                ]
    return words_new

# %%
import csv

filename = 'data/labeledTrainData.tsv'
review_ids = []
reviews = []
labels = []
#importing dataset into lists
wrong_temp = []
#[92, 102, 120, 259, 404, 1028, 1094, 1184, 1229, 1234, 1343, 1503, 1790, 1861, 2212, 3430, 3771, 3870, 4106, 4407, 4866, 5053, 5218, 5221, 5514, 5553, 5646, 5853, 6086, 6499, 6582, 6746, 7021, 7023, 7194, 7331, 7454, 7473, 7553, 7837, 8119, 8264, 8407, 8433, 8971, 9076, 9204, 9402, 9490, 9552, 9562, 9632, 9716, 9748, 9787, 10107, 10230, 10233, 10414, 10477, 10500, 10702, 10892, 11048, 11055, 11371, 11375, 11513, 11744, 11944, 12071, 12159, 12188, 12243, 12341, 12558, 12594, 12808, 13087, 13159, 14111, 14755, 14860, 14993, 15094, 15260, 15352, 15360, 15656, 15871, 16214, 16274, 16492, 16539, 16613, 16622, 16870, 16949, 16990, 16992, 17071, 17254, 17371, 17450, 17463, 17603, 17709, 17712, 17749, 18024, 18221, 18226, 18681, 18784, 18896, 19063, 19609, 19714, 19889]

with open(filename, 'r') as f:
    next(f)
    reader = csv.reader(f, delimiter='\t')
    row_count = 0
    for row in reader:
        review_ids.append(row[0])
        labels.append([int(row[1])] )
        reviews.append(row[2])

# %%
reviews_pp = []
words = []

for review in reviews:
    review_pp = preprocess(review)
    reviews_pp.append(review_pp)
    words.extend(review_pp)
    
words = removing_noise(words)

# %%
#Converting word to integers and making the vocabulary
vocab = set(words)
vocab_size = len(vocab)
words_count = Counter(words)
sorted_vocab = sorted(words_count, key = words_count.get, reverse = True)
word_to_int = {word:i for i,word in enumerate(sorted_vocab,1)}

#Converting each review in the form of integers
reviews_pp_ints = []
for review in reviews_pp:
    this_review_int = []
    for word in review:
        if word in vocab:
            this_review_int.append(word_to_int[word])
    reviews_pp_ints.append(this_review_int)

# %%
len(reviews_pp_ints[0])
# Out:
# 412

# %%
len(reviews_pp[0])
# Out:
# 429

# %%
len(reviews_pp_ints)
# Out:
# 25000

# %%
max_seq_len = 200
features = np.zeros((len(reviews_pp_ints), max_seq_len), dtype=int)
for i, row in enumerate(reviews_pp_ints):
    features[i, :len(row)] = np.array(row[:max_seq_len] )

# %%
# 'features' is a 2d array storing all sequences

# %% [markdown]
# ## Train Test Validation split

# %%
split_frac = 0.8
split_idx = int(len(features)*0.8)
train_x, val_x = features[:split_idx], features[split_idx:]
train_y, val_y = labels[:split_idx], labels[split_idx:]

test_idx = int(len(val_x)*0.5)
val_x, test_x = val_x[:test_idx], val_x[test_idx:]
val_y, test_y = val_y[:test_idx], val_y[test_idx:]

# %% [markdown]
# ## Building Network

# %%
input_size = 200
embed_size = 300
lstm_size = 150
lstm_layers = 1
batch_size = 500
hidden_nodes = 10


X = tf.placeholder(tf.int32, [None, None], name = 'inputs')
Y = tf.placeholder(tf.float32, [None, 1], name = 'labels')

tf.set_random_seed(5)

embedding = tf.Variable(tf.random_uniform((vocab_size+1, embed_size), -1, 1))
embed = tf.nn.embedding_lookup(embedding, X)

lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)
cell = tf.contrib.rnn.MultiRNNCell([lstm]*lstm_layers)

#getting an initial state of zeros\n",
initial_state = cell.zero_state(batch_size, tf.float32)

outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state = initial_state)

#hidden_layer = tf.contrib.layers.fully_connected(outputs[:, -1], hidden_nodes, activation_fn=tf.nn.relu)
predictions = tf.contrib.layers.fully_connected(outputs[:, -1],1, activation_fn=tf.sigmoid)
#predictions,Y\n",

loss = tf.reduce_mean(tf.square(Y - predictions))
optimizer = tf.train.AdamOptimizer(0.01).minimize(loss)

# %%
#Accuracy:
correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.float32), Y)
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %% [markdown]
# ## Training

# %%
n_epochs = 60

# %%
def get_batches(x, y, batch_size=100):
    
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for e in range(n_epochs):
    state = sess.run(initial_state)
    iteration = 1

    for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
        feed = {X: x, Y: y, initial_state: state}

        state, loss_,  _ = sess.run([final_state, loss, optimizer], feed_dict=feed)

        if iteration%5==0:
            print("Epoch: {}/{}".format(e, n_epochs),
                  "Iteration: {}".format(iteration),
                  "Train loss: {:.5f}".format(loss_))

        if iteration%25==0:
            val_acc = []
            val_state = sess.run(cell.zero_state(batch_size, tf.float32))
            for x, y in get_batches(val_x, val_y, batch_size):
                feed = {X: x,
                        Y: y,
                        initial_state: val_state}
                batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
                val_acc.append(batch_acc)
            print("Val acc: {:.5f}".format(np.mean(val_acc)))

        if iteration%25==0:
            train_acc = []
            train_state = sess.run(cell.zero_state(batch_size, tf.float32))
            for x, y in get_batches(train_x, train_y, batch_size):
                feed = {X: x,
                        Y: y,
                        initial_state: train_state}
                batch_acc, train_state, corr = sess.run([accuracy, final_state, correct_pred], feed_dict=feed)
                bad_indexes = [index for index, correctness in enumerate(corr) if correctness ==0 ]
                train_acc.append(batch_acc)
            print("Train acc: {:.5f}".format(np.mean(train_acc)))

        iteration +=1

train_acc = []
train_state = sess.run(cell.zero_state(batch_size, tf.float32))
i = 0
wrong = []
for x, y in get_batches(train_x, train_y, batch_size):
    feed = {X: x,
            Y: y,
            initial_state: train_state}
    batch_acc, train_state, corr = sess.run([accuracy, final_state, correct_pred], feed_dict=feed)
    bad_indexes = [(index + i*500) for index, correctness in enumerate(corr) if correctness ==0 ]
    i = i+1
    wrong.extend(bad_indexes)
    #print(bad_indexes)
    train_acc.append(batch_acc)
print("Train acc: {:.5f}".format(np.mean(train_acc)))
print('Training Completed')
print(wrong)


test_acc = []

test_state = sess.run(cell.zero_state(batch_size, tf.float32))
for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
    feed = {X: x,Y: y,initial_state: test_state}

    batch_acc, test_state = sess.run([accuracy, final_state], feed_dict=feed)
    test_acc.append(batch_acc)

print("Test accuracy: {:.5f}".format(np.mean(test_acc)))
# Out:
# Epoch: 0/60 Iteration: 5 Train loss: 0.403
# Epoch: 0/60 Iteration: 10 Train loss: 0.392
# Epoch: 0/60 Iteration: 15 Train loss: 0.381
# Epoch: 0/60 Iteration: 20 Train loss: 0.257
# Epoch: 0/60 Iteration: 25 Train loss: 0.298
# Val acc: 0.487
# Train acc: 0.523
# Epoch: 0/60 Iteration: 30 Train loss: 0.257
# Epoch: 0/60 Iteration: 35 Train loss: 0.255
# Epoch: 0/60 Iteration: 40 Train loss: 0.258
# Epoch: 1/60 Iteration: 5 Train loss: 0.231
# Epoch: 1/60 Iteration: 10 Train loss: 0.210
# Epoch: 1/60 Iteration: 15 Train loss: 0.256
# Epoch: 1/60 Iteration: 20 Train loss: 0.286
# Epoch: 1/60 Iteration: 25 Train loss: 0.242
# Val acc: 0.517
# Train acc: 0.593
# Epoch: 1/60 Iteration: 30 Train loss: 0.225
# Epoch: 1/60 Iteration: 35 Train loss: 0.214
# Epoch: 1/60 Iteration: 40 Train loss: 0.217
# Epoch: 2/60 Iteration: 5 Train loss: 0.213
# Epoch: 2/60 Iteration: 10 Train loss: 0.201
# Epoch: 2/60 Iteration: 15 Train loss: 0.209
# Epoch: 2/60 Iteration: 20 Train loss: 0.212
# Epoch: 2/60 Iteration: 25 Train loss: 0.201
# Val acc: 0.548
# Train acc: 0.664
# Epoch: 2/60 Iteration: 30 Train loss: 0.196
# Epoch: 2/60 Iteration: 35 Train loss: 0.181
# Epoch: 2/60 Iteration: 40 Train loss: 0.191
# Epoch: 3/60 Iteration: 5 Train loss: 0.162
# Epoch: 3/60 Iteration: 10 Train loss: 0.164
# Epoch: 3/60 Iteration: 15 Train loss: 0.167
# Epoch: 3/60 Iteration: 20 Train loss: 0.156
# Epoch: 3/60 Iteration: 25 Train loss: 0.130
# Val acc: 0.734
# Train acc: 0.862
# Epoch: 3/60 Iteration: 30 Train loss: 0.118
# Epoch: 3/60 Iteration: 35 Train loss: 0.111
# Epoch: 3/60 Iteration: 40 Train loss: 0.136
# Epoch: 4/60 Iteration: 5 Train loss: 0.092
# Epoch: 4/60 Iteration: 10 Train loss: 0.086
# Epoch: 4/60 Iteration: 15 Train loss: 0.090
# Epoch: 4/60 Iteration: 20 Train loss: 0.104
# Epoch: 4/60 Iteration: 25 Train loss: 0.074
# Val acc: 0.785
# Train acc: 0.934
# Epoch: 4/60 Iteration: 30 Train loss: 0.067
# Epoch: 4/60 Iteration: 35 Train loss: 0.056
# Epoch: 4/60 Iteration: 40 Train loss: 0.079
# Epoch: 5/60 Iteration: 5 Train loss: 0.060
# Epoch: 5/60 Iteration: 10 Train loss: 0.052
# Epoch: 5/60 Iteration: 15 Train loss: 0.064
# Epoch: 5/60 Iteration: 20 Train loss: 0.075
# Epoch: 5/60 Iteration: 25 Train loss: 0.047
# Val acc: 0.788
# Train acc: 0.961
# Epoch: 5/60 Iteration: 30 Train loss: 0.053
# Epoch: 5/60 Iteration: 35 Train loss: 0.031
# Epoch: 5/60 Iteration: 40 Train loss: 0.055
# Epoch: 6/60 Iteration: 5 Train loss: 0.026
# Epoch: 6/60 Iteration: 10 Train loss: 0.030
# Epoch: 6/60 Iteration: 15 Train loss: 0.034
# Epoch: 6/60 Iteration: 20 Train loss: 0.033
# Epoch: 6/60 Iteration: 25 Train loss: 0.025
# Val acc: 0.801
# Train acc: 0.977
# Epoch: 6/60 Iteration: 30 Train loss: 0.036
# Epoch: 6/60 Iteration: 35 Train loss: 0.025
# Epoch: 6/60 Iteration: 40 Train loss: 0.026
# Epoch: 7/60 Iteration: 5 Train loss: 0.016
# Epoch: 7/60 Iteration: 10 Train loss: 0.016
# Epoch: 7/60 Iteration: 15 Train loss: 0.026
# Epoch: 7/60 Iteration: 20 Train loss: 0.022
# Epoch: 7/60 Iteration: 25 Train loss: 0.018
# Val acc: 0.812
# Train acc: 0.985
# Epoch: 7/60 Iteration: 30 Train loss: 0.020
# Epoch: 7/60 Iteration: 35 Train loss: 0.017
# Epoch: 7/60 Iteration: 40 Train loss: 0.017
# Epoch: 8/60 Iteration: 5 Train loss: 0.010
# Epoch: 8/60 Iteration: 10 Train loss: 0.011
# Epoch: 8/60 Iteration: 15 Train loss: 0.027
# Epoch: 8/60 Iteration: 20 Train loss: 0.019
# Epoch: 8/60 Iteration: 25 Train loss: 0.010
# Val acc: 0.798
# Train acc: 0.987
# Epoch: 8/60 Iteration: 30 Train loss: 0.020
# Epoch: 8/60 Iteration: 35 Train loss: 0.017
# Epoch: 8/60 Iteration: 40 Train loss: 0.015
# Epoch: 9/60 Iteration: 5 Train loss: 0.011
# Epoch: 9/60 Iteration: 10 Train loss: 0.012
# Epoch: 9/60 Iteration: 15 Train loss: 0.022
# Epoch: 9/60 Iteration: 20 Train loss: 0.020
# Epoch: 9/60 Iteration: 25 Train loss: 0.012
# Val acc: 0.787
# Train acc: 0.985
# Epoch: 9/60 Iteration: 30 Train loss: 0.013
# Epoch: 9/60 Iteration: 35 Train loss: 0.013
# Epoch: 9/60 Iteration: 40 Train loss: 0.023
# Epoch: 10/60 Iteration: 5 Train loss: 0.007
# Epoch: 10/60 Iteration: 10 Train loss: 0.015
# Epoch: 10/60 Iteration: 15 Train loss: 0.016
# Epoch: 10/60 Iteration: 20 Train loss: 0.014
# Epoch: 10/60 Iteration: 25 Train loss: 0.007
# Val acc: 0.786
# Train acc: 0.991
# Epoch: 10/60 Iteration: 30 Train loss: 0.011
# Epoch: 10/60 Iteration: 35 Train loss: 0.012
# Epoch: 10/60 Iteration: 40 Train loss: 0.012
# Epoch: 11/60 Iteration: 5 Train loss: 0.006
# Epoch: 11/60 Iteration: 10 Train loss: 0.011
# Epoch: 11/60 Iteration: 15 Train loss: 0.014
# Epoch: 11/60 Iteration: 20 Train loss: 0.014
# Epoch: 11/60 Iteration: 25 Train loss: 0.006
# Val acc: 0.790
# Train acc: 0.992
# Epoch: 11/60 Iteration: 30 Train loss: 0.009
# Epoch: 11/60 Iteration: 35 Train loss: 0.013
# Epoch: 11/60 Iteration: 40 Train loss: 0.011
# Epoch: 12/60 Iteration: 5 Train loss: 0.009
# Epoch: 12/60 Iteration: 10 Train loss: 0.007
# Epoch: 12/60 Iteration: 15 Train loss: 0.014
# Epoch: 12/60 Iteration: 20 Train loss: 0.010
# Epoch: 12/60 Iteration: 25 Train loss: 0.008
# Val acc: 0.779
# Train acc: 0.992
# Epoch: 12/60 Iteration: 30 Train loss: 0.006
# Epoch: 12/60 Iteration: 35 Train loss: 0.011
# Epoch: 12/60 Iteration: 40 Train loss: 0.010
# Epoch: 13/60 Iteration: 5 Train loss: 0.009
# Epoch: 13/60 Iteration: 10 Train loss: 0.005
# Epoch: 13/60 Iteration: 15 Train loss: 0.014
# Epoch: 13/60 Iteration: 20 Train loss: 0.005
# Epoch: 13/60 Iteration: 25 Train loss: 0.011
# Val acc: 0.775
# Train acc: 0.990
# Epoch: 13/60 Iteration: 30 Train loss: 0.008
# Epoch: 13/60 Iteration: 35 Train loss: 0.018
# Epoch: 13/60 Iteration: 40 Train loss: 0.009
# Epoch: 14/60 Iteration: 5 Train loss: 0.007
# Epoch: 14/60 Iteration: 10 Train loss: 0.005
# Epoch: 14/60 Iteration: 15 Train loss: 0.022
# Epoch: 14/60 Iteration: 20 Train loss: 0.007
# Epoch: 14/60 Iteration: 25 Train loss: 0.010
# Val acc: 0.768
# Train acc: 0.981
# Epoch: 14/60 Iteration: 30 Train loss: 0.012
# Epoch: 14/60 Iteration: 35 Train loss: 0.014
# Epoch: 14/60 Iteration: 40 Train loss: 0.010
# Epoch: 15/60 Iteration: 5 Train loss: 0.008
# Epoch: 15/60 Iteration: 10 Train loss: 0.006
# Epoch: 15/60 Iteration: 15 Train loss: 0.018
# Epoch: 15/60 Iteration: 20 Train loss: 0.007
# Epoch: 15/60 Iteration: 25 Train loss: 0.006
# Val acc: 0.775
# Train acc: 0.985
# Epoch: 15/60 Iteration: 30 Train loss: 0.015
# Epoch: 15/60 Iteration: 35 Train loss: 0.008
# Epoch: 15/60 Iteration: 40 Train loss: 0.027
# Epoch: 16/60 Iteration: 5 Train loss: 0.009
# Epoch: 16/60 Iteration: 10 Train loss: 0.014
# Epoch: 16/60 Iteration: 15 Train loss: 0.011
# Epoch: 16/60 Iteration: 20 Train loss: 0.006
# Epoch: 16/60 Iteration: 25 Train loss: 0.007
# Val acc: 0.791
# Train acc: 0.993
# Epoch: 16/60 Iteration: 30 Train loss: 0.010
# Epoch: 16/60 Iteration: 35 Train loss: 0.015
# Epoch: 16/60 Iteration: 40 Train loss: 0.010
# Epoch: 17/60 Iteration: 5 Train loss: 0.014
# Epoch: 17/60 Iteration: 10 Train loss: 0.006
# Epoch: 17/60 Iteration: 15 Train loss: 0.023
# Epoch: 17/60 Iteration: 20 Train loss: 0.004
# Epoch: 17/60 Iteration: 25 Train loss: 0.020
# Val acc: 0.765
# Train acc: 0.986
# Epoch: 17/60 Iteration: 30 Train loss: 0.015
# Epoch: 17/60 Iteration: 35 Train loss: 0.015
# Epoch: 17/60 Iteration: 40 Train loss: 0.010
# Epoch: 18/60 Iteration: 5 Train loss: 0.012
# Epoch: 18/60 Iteration: 10 Train loss: 0.006
# Epoch: 18/60 Iteration: 15 Train loss: 0.012
# Epoch: 18/60 Iteration: 20 Train loss: 0.012
# Epoch: 18/60 Iteration: 25 Train loss: 0.005
# Val acc: 0.780
# Train acc: 0.994
# Epoch: 18/60 Iteration: 30 Train loss: 0.008
# Epoch: 18/60 Iteration: 35 Train loss: 0.007
# Epoch: 18/60 Iteration: 40 Train loss: 0.013
# Epoch: 19/60 Iteration: 5 Train loss: 0.008
# Epoch: 19/60 Iteration: 10 Train loss: 0.006
# Epoch: 19/60 Iteration: 15 Train loss: 0.015
# Epoch: 19/60 Iteration: 20 Train loss: 0.009
# Epoch: 19/60 Iteration: 25 Train loss: 0.008
# Val acc: 0.784
# Train acc: 0.993
# Epoch: 19/60 Iteration: 30 Train loss: 0.008
# Epoch: 19/60 Iteration: 35 Train loss: 0.009
# Epoch: 19/60 Iteration: 40 Train loss: 0.010
# Epoch: 20/60 Iteration: 5 Train loss: 0.005
# Epoch: 20/60 Iteration: 10 Train loss: 0.006
# Epoch: 20/60 Iteration: 15 Train loss: 0.011
# Epoch: 20/60 Iteration: 20 Train loss: 0.004
# Epoch: 20/60 Iteration: 25 Train loss: 0.005
# Val acc: 0.797
# Train acc: 0.996
# Epoch: 20/60 Iteration: 30 Train loss: 0.006
# Epoch: 20/60 Iteration: 35 Train loss: 0.006
# Epoch: 20/60 Iteration: 40 Train loss: 0.006
# Epoch: 21/60 Iteration: 5 Train loss: 0.005
# Epoch: 21/60 Iteration: 10 Train loss: 0.003
# Epoch: 21/60 Iteration: 15 Train loss: 0.010
# Epoch: 21/60 Iteration: 20 Train loss: 0.002
# Epoch: 21/60 Iteration: 25 Train loss: 0.003
# Val acc: 0.793
# Train acc: 0.997
# Epoch: 21/60 Iteration: 30 Train loss: 0.006
# Epoch: 21/60 Iteration: 35 Train loss: 0.005
# Epoch: 21/60 Iteration: 40 Train loss: 0.007
# Epoch: 22/60 Iteration: 5 Train loss: 0.004
# Epoch: 22/60 Iteration: 10 Train loss: 0.003
# Epoch: 22/60 Iteration: 15 Train loss: 0.010
# Epoch: 22/60 Iteration: 20 Train loss: 0.002
# Epoch: 22/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.793
# Train acc: 0.997
# Epoch: 22/60 Iteration: 30 Train loss: 0.006
# Epoch: 22/60 Iteration: 35 Train loss: 0.005
# Epoch: 22/60 Iteration: 40 Train loss: 0.005
# Epoch: 23/60 Iteration: 5 Train loss: 0.003
# Epoch: 23/60 Iteration: 10 Train loss: 0.003
# Epoch: 23/60 Iteration: 15 Train loss: 0.009
# Epoch: 23/60 Iteration: 20 Train loss: 0.002
# Epoch: 23/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.794
# Train acc: 0.997
# Epoch: 23/60 Iteration: 30 Train loss: 0.006
# Epoch: 23/60 Iteration: 35 Train loss: 0.005
# Epoch: 23/60 Iteration: 40 Train loss: 0.004
# Epoch: 24/60 Iteration: 5 Train loss: 0.003
# Epoch: 24/60 Iteration: 10 Train loss: 0.002
# Epoch: 24/60 Iteration: 15 Train loss: 0.009
# Epoch: 24/60 Iteration: 20 Train loss: 0.002
# Epoch: 24/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.793
# Train acc: 0.997
# Epoch: 24/60 Iteration: 30 Train loss: 0.006
# Epoch: 24/60 Iteration: 35 Train loss: 0.004
# Epoch: 24/60 Iteration: 40 Train loss: 0.004
# Epoch: 25/60 Iteration: 5 Train loss: 0.003
# Epoch: 25/60 Iteration: 10 Train loss: 0.002
# Epoch: 25/60 Iteration: 15 Train loss: 0.009
# Epoch: 25/60 Iteration: 20 Train loss: 0.002
# Epoch: 25/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.793
# Train acc: 0.997
# Epoch: 25/60 Iteration: 30 Train loss: 0.006
# Epoch: 25/60 Iteration: 35 Train loss: 0.004
# Epoch: 25/60 Iteration: 40 Train loss: 0.004
# Epoch: 26/60 Iteration: 5 Train loss: 0.003
# Epoch: 26/60 Iteration: 10 Train loss: 0.002
# Epoch: 26/60 Iteration: 15 Train loss: 0.008
# Epoch: 26/60 Iteration: 20 Train loss: 0.002
# Epoch: 26/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.795
# Train acc: 0.997
# Epoch: 26/60 Iteration: 30 Train loss: 0.006
# Epoch: 26/60 Iteration: 35 Train loss: 0.003
# Epoch: 26/60 Iteration: 40 Train loss: 0.004
# Epoch: 27/60 Iteration: 5 Train loss: 0.003
# Epoch: 27/60 Iteration: 10 Train loss: 0.002
# Epoch: 27/60 Iteration: 15 Train loss: 0.008
# Epoch: 27/60 Iteration: 20 Train loss: 0.002
# Epoch: 27/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.796
# Train acc: 0.997
# Epoch: 27/60 Iteration: 30 Train loss: 0.006
# Epoch: 27/60 Iteration: 35 Train loss: 0.003
# Epoch: 27/60 Iteration: 40 Train loss: 0.004
# Epoch: 28/60 Iteration: 5 Train loss: 0.003
# Epoch: 28/60 Iteration: 10 Train loss: 0.002
# Epoch: 28/60 Iteration: 15 Train loss: 0.008
# Epoch: 28/60 Iteration: 20 Train loss: 0.002
# Epoch: 28/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.798
# Train acc: 0.998
# Epoch: 28/60 Iteration: 30 Train loss: 0.005
# Epoch: 28/60 Iteration: 35 Train loss: 0.002
# Epoch: 28/60 Iteration: 40 Train loss: 0.004
# Epoch: 29/60 Iteration: 5 Train loss: 0.002
# Epoch: 29/60 Iteration: 10 Train loss: 0.002
# Epoch: 29/60 Iteration: 15 Train loss: 0.007
# Epoch: 29/60 Iteration: 20 Train loss: 0.002
# Epoch: 29/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.800
# Train acc: 0.998
# Epoch: 29/60 Iteration: 30 Train loss: 0.005
# Epoch: 29/60 Iteration: 35 Train loss: 0.002
# Epoch: 29/60 Iteration: 40 Train loss: 0.004
# Epoch: 30/60 Iteration: 5 Train loss: 0.002
# Epoch: 30/60 Iteration: 10 Train loss: 0.002
# Epoch: 30/60 Iteration: 15 Train loss: 0.007
# Epoch: 30/60 Iteration: 20 Train loss: 0.002
# Epoch: 30/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.799
# Train acc: 0.998
# Epoch: 30/60 Iteration: 30 Train loss: 0.005
# Epoch: 30/60 Iteration: 35 Train loss: 0.002
# Epoch: 30/60 Iteration: 40 Train loss: 0.004
# Epoch: 31/60 Iteration: 5 Train loss: 0.002
# Epoch: 31/60 Iteration: 10 Train loss: 0.002
# Epoch: 31/60 Iteration: 15 Train loss: 0.006
# Epoch: 31/60 Iteration: 20 Train loss: 0.002
# Epoch: 31/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.800
# Train acc: 0.998
# Epoch: 31/60 Iteration: 30 Train loss: 0.005
# Epoch: 31/60 Iteration: 35 Train loss: 0.002
# Epoch: 31/60 Iteration: 40 Train loss: 0.004
# Epoch: 32/60 Iteration: 5 Train loss: 0.002
# Epoch: 32/60 Iteration: 10 Train loss: 0.002
# Epoch: 32/60 Iteration: 15 Train loss: 0.005
# Epoch: 32/60 Iteration: 20 Train loss: 0.001
# Epoch: 32/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.798
# Train acc: 0.998
# Epoch: 32/60 Iteration: 30 Train loss: 0.005
# Epoch: 32/60 Iteration: 35 Train loss: 0.002
# Epoch: 32/60 Iteration: 40 Train loss: 0.004
# Epoch: 33/60 Iteration: 5 Train loss: 0.002
# Epoch: 33/60 Iteration: 10 Train loss: 0.002
# Epoch: 33/60 Iteration: 15 Train loss: 0.004
# Epoch: 33/60 Iteration: 20 Train loss: 0.001
# Epoch: 33/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.799
# Train acc: 0.998
# Epoch: 33/60 Iteration: 30 Train loss: 0.004
# Epoch: 33/60 Iteration: 35 Train loss: 0.002
# Epoch: 33/60 Iteration: 40 Train loss: 0.004
# Epoch: 34/60 Iteration: 5 Train loss: 0.002
# Epoch: 34/60 Iteration: 10 Train loss: 0.002
# Epoch: 34/60 Iteration: 15 Train loss: 0.004
# Epoch: 34/60 Iteration: 20 Train loss: 0.001
# Epoch: 34/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.801
# Train acc: 0.998
# Epoch: 34/60 Iteration: 30 Train loss: 0.004
# Epoch: 34/60 Iteration: 35 Train loss: 0.002
# Epoch: 34/60 Iteration: 40 Train loss: 0.004
# Epoch: 35/60 Iteration: 5 Train loss: 0.002
# Epoch: 35/60 Iteration: 10 Train loss: 0.002
# Epoch: 35/60 Iteration: 15 Train loss: 0.003
# Epoch: 35/60 Iteration: 20 Train loss: 0.000
# Epoch: 35/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.801
# Train acc: 0.998
# Epoch: 35/60 Iteration: 30 Train loss: 0.004
# Epoch: 35/60 Iteration: 35 Train loss: 0.002
# Epoch: 35/60 Iteration: 40 Train loss: 0.004
# Epoch: 36/60 Iteration: 5 Train loss: 0.002
# Epoch: 36/60 Iteration: 10 Train loss: 0.002
# Epoch: 36/60 Iteration: 15 Train loss: 0.003
# Epoch: 36/60 Iteration: 20 Train loss: 0.000
# Epoch: 36/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.802
# Train acc: 0.998
# Epoch: 36/60 Iteration: 30 Train loss: 0.004
# Epoch: 36/60 Iteration: 35 Train loss: 0.002
# Epoch: 36/60 Iteration: 40 Train loss: 0.004
# Epoch: 37/60 Iteration: 5 Train loss: 0.002
# Epoch: 37/60 Iteration: 10 Train loss: 0.002
# Epoch: 37/60 Iteration: 15 Train loss: 0.003
# Epoch: 37/60 Iteration: 20 Train loss: 0.000
# Epoch: 37/60 Iteration: 25 Train loss: 0.003
# Val acc: 0.802
# Train acc: 0.998
# Epoch: 37/60 Iteration: 30 Train loss: 0.003
# Epoch: 37/60 Iteration: 35 Train loss: 0.002
# Epoch: 37/60 Iteration: 40 Train loss: 0.004
# Epoch: 38/60 Iteration: 5 Train loss: 0.002
# Epoch: 38/60 Iteration: 10 Train loss: 0.002
# Epoch: 38/60 Iteration: 15 Train loss: 0.003
# Epoch: 38/60 Iteration: 20 Train loss: 0.000
# Epoch: 38/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.801
# Train acc: 0.998
# Epoch: 38/60 Iteration: 30 Train loss: 0.003
# Epoch: 38/60 Iteration: 35 Train loss: 0.002
# Epoch: 38/60 Iteration: 40 Train loss: 0.004
# Epoch: 39/60 Iteration: 5 Train loss: 0.002
# Epoch: 39/60 Iteration: 10 Train loss: 0.002
# Epoch: 39/60 Iteration: 15 Train loss: 0.003
# Epoch: 39/60 Iteration: 20 Train loss: 0.000
# Epoch: 39/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.800
# Train acc: 0.998
# Epoch: 39/60 Iteration: 30 Train loss: 0.004
# Epoch: 39/60 Iteration: 35 Train loss: 0.002
# Epoch: 39/60 Iteration: 40 Train loss: 0.004
# Epoch: 40/60 Iteration: 5 Train loss: 0.002
# Epoch: 40/60 Iteration: 10 Train loss: 0.002
# Epoch: 40/60 Iteration: 15 Train loss: 0.003
# Epoch: 40/60 Iteration: 20 Train loss: 0.000
# Epoch: 40/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.798
# Train acc: 0.998
# Epoch: 40/60 Iteration: 30 Train loss: 0.003
# Epoch: 40/60 Iteration: 35 Train loss: 0.002
# Epoch: 40/60 Iteration: 40 Train loss: 0.004
# Epoch: 41/60 Iteration: 5 Train loss: 0.002
# Epoch: 41/60 Iteration: 10 Train loss: 0.002
# Epoch: 41/60 Iteration: 15 Train loss: 0.003
# Epoch: 41/60 Iteration: 20 Train loss: 0.000
# Epoch: 41/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.799
# Train acc: 0.998
# Epoch: 41/60 Iteration: 30 Train loss: 0.004
# Epoch: 41/60 Iteration: 35 Train loss: 0.002
# Epoch: 41/60 Iteration: 40 Train loss: 0.004
# Epoch: 42/60 Iteration: 5 Train loss: 0.002
# Epoch: 42/60 Iteration: 10 Train loss: 0.002
# Epoch: 42/60 Iteration: 15 Train loss: 0.003
# Epoch: 42/60 Iteration: 20 Train loss: 0.000
# Epoch: 42/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.798
# Train acc: 0.998
# Epoch: 42/60 Iteration: 30 Train loss: 0.003
# Epoch: 42/60 Iteration: 35 Train loss: 0.002
# Epoch: 42/60 Iteration: 40 Train loss: 0.004
# Epoch: 43/60 Iteration: 5 Train loss: 0.002
# Epoch: 43/60 Iteration: 10 Train loss: 0.002
# Epoch: 43/60 Iteration: 15 Train loss: 0.003
# Epoch: 43/60 Iteration: 20 Train loss: 0.000
# Epoch: 43/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.798
# Train acc: 0.999
# Epoch: 43/60 Iteration: 30 Train loss: 0.002
# Epoch: 43/60 Iteration: 35 Train loss: 0.002
# Epoch: 43/60 Iteration: 40 Train loss: 0.004
# Epoch: 44/60 Iteration: 5 Train loss: 0.002
# Epoch: 44/60 Iteration: 10 Train loss: 0.002
# Epoch: 44/60 Iteration: 15 Train loss: 0.002
# Epoch: 44/60 Iteration: 20 Train loss: 0.000
# Epoch: 44/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.799
# Train acc: 0.999
# Epoch: 44/60 Iteration: 30 Train loss: 0.002
# Epoch: 44/60 Iteration: 35 Train loss: 0.002
# Epoch: 44/60 Iteration: 40 Train loss: 0.004
# Epoch: 45/60 Iteration: 5 Train loss: 0.002
# Epoch: 45/60 Iteration: 10 Train loss: 0.002
# Epoch: 45/60 Iteration: 15 Train loss: 0.002
# Epoch: 45/60 Iteration: 20 Train loss: 0.000
# Epoch: 45/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.798
# Train acc: 0.999
# Epoch: 45/60 Iteration: 30 Train loss: 0.001
# Epoch: 45/60 Iteration: 35 Train loss: 0.001
# Epoch: 45/60 Iteration: 40 Train loss: 0.004
# Epoch: 46/60 Iteration: 5 Train loss: 0.002
# Epoch: 46/60 Iteration: 10 Train loss: 0.002
# Epoch: 46/60 Iteration: 15 Train loss: 0.002
# Epoch: 46/60 Iteration: 20 Train loss: 0.000
# Epoch: 46/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.799
# Train acc: 0.999
# Epoch: 46/60 Iteration: 30 Train loss: 0.001
# Epoch: 46/60 Iteration: 35 Train loss: 0.001
# Epoch: 46/60 Iteration: 40 Train loss: 0.004
# Epoch: 47/60 Iteration: 5 Train loss: 0.002
# Epoch: 47/60 Iteration: 10 Train loss: 0.002
# Epoch: 47/60 Iteration: 15 Train loss: 0.002
# Epoch: 47/60 Iteration: 20 Train loss: 0.000
# Epoch: 47/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.800
# Train acc: 0.999
# Epoch: 47/60 Iteration: 30 Train loss: 0.001
# Epoch: 47/60 Iteration: 35 Train loss: 0.000
# Epoch: 47/60 Iteration: 40 Train loss: 0.004
# Epoch: 48/60 Iteration: 5 Train loss: 0.002
# Epoch: 48/60 Iteration: 10 Train loss: 0.002
# Epoch: 48/60 Iteration: 15 Train loss: 0.002
# Epoch: 48/60 Iteration: 20 Train loss: 0.000
# Epoch: 48/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.801
# Train acc: 0.999
# Epoch: 48/60 Iteration: 30 Train loss: 0.001
# Epoch: 48/60 Iteration: 35 Train loss: 0.000
# Epoch: 48/60 Iteration: 40 Train loss: 0.004
# Epoch: 49/60 Iteration: 5 Train loss: 0.002
# Epoch: 49/60 Iteration: 10 Train loss: 0.002
# Epoch: 49/60 Iteration: 15 Train loss: 0.002
# Epoch: 49/60 Iteration: 20 Train loss: 0.000
# Epoch: 49/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.800
# Train acc: 0.999
# Epoch: 49/60 Iteration: 30 Train loss: 0.001
# Epoch: 49/60 Iteration: 35 Train loss: 0.000
# Epoch: 49/60 Iteration: 40 Train loss: 0.004
# Epoch: 50/60 Iteration: 5 Train loss: 0.002
# Epoch: 50/60 Iteration: 10 Train loss: 0.002
# Epoch: 50/60 Iteration: 15 Train loss: 0.002
# Epoch: 50/60 Iteration: 20 Train loss: 0.000
# Epoch: 50/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.802
# Train acc: 0.999
# Epoch: 50/60 Iteration: 30 Train loss: 0.001
# Epoch: 50/60 Iteration: 35 Train loss: 0.000
# Epoch: 50/60 Iteration: 40 Train loss: 0.004
# Epoch: 51/60 Iteration: 5 Train loss: 0.002
# Epoch: 51/60 Iteration: 10 Train loss: 0.002
# Epoch: 51/60 Iteration: 15 Train loss: 0.002
# Epoch: 51/60 Iteration: 20 Train loss: 0.000
# Epoch: 51/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.801
# Train acc: 0.999
# Epoch: 51/60 Iteration: 30 Train loss: 0.001
# Epoch: 51/60 Iteration: 35 Train loss: 0.000
# Epoch: 51/60 Iteration: 40 Train loss: 0.004
# Epoch: 52/60 Iteration: 5 Train loss: 0.002
# Epoch: 52/60 Iteration: 10 Train loss: 0.002
# Epoch: 52/60 Iteration: 15 Train loss: 0.002
# Epoch: 52/60 Iteration: 20 Train loss: 0.000
# Epoch: 52/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.801
# Train acc: 0.999
# Epoch: 52/60 Iteration: 30 Train loss: 0.001
# Epoch: 52/60 Iteration: 35 Train loss: 0.000
# Epoch: 52/60 Iteration: 40 Train loss: 0.004
# Epoch: 53/60 Iteration: 5 Train loss: 0.002
# Epoch: 53/60 Iteration: 10 Train loss: 0.002
# Epoch: 53/60 Iteration: 15 Train loss: 0.002
# Epoch: 53/60 Iteration: 20 Train loss: 0.000
# Epoch: 53/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.802
# Train acc: 0.999
# Epoch: 53/60 Iteration: 30 Train loss: 0.001
# Epoch: 53/60 Iteration: 35 Train loss: 0.000
# Epoch: 53/60 Iteration: 40 Train loss: 0.004
# Epoch: 54/60 Iteration: 5 Train loss: 0.002
# Epoch: 54/60 Iteration: 10 Train loss: 0.002
# Epoch: 54/60 Iteration: 15 Train loss: 0.002
# Epoch: 54/60 Iteration: 20 Train loss: 0.000
# Epoch: 54/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.802
# Train acc: 0.999
# Epoch: 54/60 Iteration: 30 Train loss: 0.001
# Epoch: 54/60 Iteration: 35 Train loss: 0.000
# Epoch: 54/60 Iteration: 40 Train loss: 0.004
# Epoch: 55/60 Iteration: 5 Train loss: 0.002
# Epoch: 55/60 Iteration: 10 Train loss: 0.002
# Epoch: 55/60 Iteration: 15 Train loss: 0.002
# Epoch: 55/60 Iteration: 20 Train loss: 0.000
# Epoch: 55/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.802
# Train acc: 0.999
# Epoch: 55/60 Iteration: 30 Train loss: 0.001
# Epoch: 55/60 Iteration: 35 Train loss: 0.000
# Epoch: 55/60 Iteration: 40 Train loss: 0.004
# Epoch: 56/60 Iteration: 5 Train loss: 0.002
# Epoch: 56/60 Iteration: 10 Train loss: 0.002
# Epoch: 56/60 Iteration: 15 Train loss: 0.002
# Epoch: 56/60 Iteration: 20 Train loss: 0.000
# Epoch: 56/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.801
# Train acc: 0.999
# Epoch: 56/60 Iteration: 30 Train loss: 0.001
# Epoch: 56/60 Iteration: 35 Train loss: 0.000
# Epoch: 56/60 Iteration: 40 Train loss: 0.004
# Epoch: 57/60 Iteration: 5 Train loss: 0.002
# Epoch: 57/60 Iteration: 10 Train loss: 0.002
# Epoch: 57/60 Iteration: 15 Train loss: 0.002
# Epoch: 57/60 Iteration: 20 Train loss: 0.000
# Epoch: 57/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.801
# Train acc: 0.999
# Epoch: 57/60 Iteration: 30 Train loss: 0.001
# Epoch: 57/60 Iteration: 35 Train loss: 0.000
# Epoch: 57/60 Iteration: 40 Train loss: 0.004
# Epoch: 58/60 Iteration: 5 Train loss: 0.002
# Epoch: 58/60 Iteration: 10 Train loss: 0.002
# Epoch: 58/60 Iteration: 15 Train loss: 0.002
# Epoch: 58/60 Iteration: 20 Train loss: 0.000
# Epoch: 58/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.802
# Train acc: 0.999
# Epoch: 58/60 Iteration: 30 Train loss: 0.001
# Epoch: 58/60 Iteration: 35 Train loss: 0.000
# Epoch: 58/60 Iteration: 40 Train loss: 0.004
# Epoch: 59/60 Iteration: 5 Train loss: 0.002
# Epoch: 59/60 Iteration: 10 Train loss: 0.002
# Epoch: 59/60 Iteration: 15 Train loss: 0.002
# Epoch: 59/60 Iteration: 20 Train loss: 0.000
# Epoch: 59/60 Iteration: 25 Train loss: 0.002
# Val acc: 0.802
# Train acc: 0.999
# Epoch: 59/60 Iteration: 30 Train loss: 0.001
# Epoch: 59/60 Iteration: 35 Train loss: 0.000
# Epoch: 59/60 Iteration: 40 Train loss: 0.004
# Train acc: 0.999
# Training Completed
# [92, 282, 1184, 2331, 2815, 2848, 3233, 4833, 7077, 7713, 7837, 8724, 9364, 10162, 10477, 12243, 14445, 15076, 18896, 19741, 19895]
# Test accuracy: 0.81480

# %%
wrong_temp = [92, 282, 1184, 2331, 2815, 2848, 3233, 4833, 7077, 7713, 7837, 8724, 9364, 10162, 10477, 12243, 14445, 15076, 18896, 19741, 19895]
for i in wrong_temp[:]:
    print('#'+str(i))
    print(reviews[i])
    print('-->Label='+str(labels[i]))
    print()
    print()
# Out:
# #92
# Okay, first of all I got this movie as a Christmas present so it was FREE! FIRST - This movie was meant to be in stereoscopic 3D. It is for the most part, but whenever the main character is in her car the movie falls flat to 2D! What!!?!?! It's not that hard to film in a car!!! SECOND - The story isn't very good. There are a lot of things wrong with it.<br /><br />THIRD - Why are they showing all of the deaths in the beginning of the film! It made the movie suck whenever some was going to get killed!!! Watch it for a good laugh , but don't waste your time buying it. Just download it or something for cheap.
# -->Label=[1]
#
#
# #282
# When I heard Patrick Swayze was finally returning to his acting career with KING SOLOMON'S MINES I was very excited. I was expecting a great Indiana Jones type action adventure. What I got was a 4 hour long (with commercials) epic that was very slow. The second and third hour could have been dropped altogether and the story would not have suffered for it. The ending was good (no spoilers here)but I was still left wanting more. Well all a guy can do is prey that Swayze does \RoadHouse 2\" so he can get back into the action genre that made him famous. Until than if your a fan of King Solomon's Mines than read the book or watch the 1985 version with Richard Chamberlain and Sharon Stone which is also not very good but its only and hour and forty minutes of your life gone instead of 4 hours."
# -->Label=[1]
#
#
# #1184
# Brilliant execution in displaying once and for all, this time in the venue of politics, of how \good intentions do actually pave the road to hell\". Excellent!"
# -->Label=[1]
#
#
# #2331
# Very nice action with an interwoven story which actually doesn't suck. Interesting enough to merit watching instead of skipping past to get to the good parts. Having Jenna Jameson and Asia Carrere helps liven it up, too. Jenna in that sweater and those glasses is just astounding! Worth picking up just to see her!
# -->Label=[1]
#
#
# #2815
# I've just seen The Saint Strikes Back for the first time and found it quite good. This was George Sanders's first appearance as the Saint, where he replaces Louis Hayward.<br /><br />In this one, the Saint is sent to San Francisco to investigate a shooting at a night club. With the help of his acquaintance Inspector Fernack who has come down from New York, they help a daughter of a crime boss.<br /><br />Joining Sanders in the cast are Wendy Barrie and Jonathan Hale.<br /><br />Not a bad Saint movie. Worth seeing.<br /><br />Rating: 3 stars out of 5.
# -->Label=[1]
#
#
# #2848
# I have spent the last week watching John Cassavetes films - starting with 'a woman under the influence' and ending on 'opening night'. I am completely and utterly blown away, in particular by these two films. from the first minute to the last in 'opening night' i was completely and utterly absorbed. i've only experienced it on a few occasions, but the feeling that this film was perfect lasted from about two thirds in, right through till the credits came up. everything about this film, from the way it was shot, the incredible performance of Gena Rowlands, the credits, the opening, the music, the plot, the sense of depth, the pace, the tenderness, the originality, the characters, the deft little moments.... for me, is truly sublime. i couldn't agree more with the previous comment about taking it to a desert island because the sheer depth of this film is something to behold. if your unlucky enough to have a house fire, i guarantee that instead of making a last ditch attempt to rescue that stash of money under your bed, you'll be rescuing your copy of this film instead.
# -->Label=[1]
#
#
# #3233
# I saw this movie with my friend and we couldnt stop laughing! i mean there was nothing scary about this movie! It was funny all the lines Freddy said were hilarious! I think they shoudln't have even made a new nightmare and just gone to Freddy Vs. jason. Although some parts were gross (like the head blowing up). and any elm street film from 1- 5 sucked. this was the best besides Number 1. I wouldnt recomend this movie if you want a good horror. But if you have nothing else to do rent this and you'll laugh alot.I want to see the texas chainsaw massacre I think it would be scary. Freddy's Dead The Final Nightmare overall grade: B-
# -->Label=[1]
#
#
# #4833
# This is a great short. i think every voice is done by jason steele. (you can only just barely tell if you've heard his normal voice though, so don't worry about them sounding the same. they don't.) its about 15 minutes long.<br /><br />edward the spatula is fighting the war against spoons and he meets some weird people. in fact, everyone he knows seem pretty crazy. <br /><br />\edward!\" \"general peterson, we have to get you to a medical unit!\" \"no, I'm not gonna make it edward.\" \"dont talk like that, I'm sure you'll be fine.\" \"im a goner edward, and you know it. before i go-\" \"yes?\" \"can i just have... one kiss?\" \"umm, no.\" \"come on, just one, small, peck on the lips?\" \"im walking away now sir.\"<br /><br />there's gonna be movie pretty soon. the date for that is in September, but its probably gonna get pushed back."
# -->Label=[1]
#
#
# #7077
# Man, if anyone was expecting a great zombie movie after reading that title, then you are a retard and you deserve to be disappointed. As for myself, I was expecting a low-budgeted cheeseball zombie flick- and that's exactly what I got. I wasn't disappointed at all. I thought it was a cool little movie. The zombies were exactly as they should be, because all of the zombies had JUST been turned, so they are freshly-undead zombies. Obviously they did that because it would've been pretty costly if they had done full-on rotted zombie FX. I understood the whole thing, I have no idea how anyone could seriously nitpick this movie. It's called \HOOD OF THE LIVING DEAD\" for the love of God! Would you watch \"Redneck Zombies\" and ANY Uwe Boll movie and actually EXPECT it to be great? Of course not! So why there are some morons on IMDb whining like school girls about this movie, I'll never understand. Oh and YES, there ARE worse movies out there, so stop saying that this was the worst you've ever seen, 'cause you know you're full of it! You ever watch \"ZOMBIEZ\"???? Or \"Feardotcom\"????? Or \"House Of The Dead\"???? THOSE are some of the worst I've ever seen. If you can't see that it's just a low- budgeted zombie movie obviously made by zombie movie fans, then something's wrong with you. I just had fun with it. Thumbs up from me and I'd also like to see a sequel."
# -->Label=[1]
#
#
# #7713
# I'm a HUGE fan of the twin sisters. Although this was one of their \not soo good\" movies. I'm not saying it's bad, I can't say it's bad, but this whole popular and not popular thingy isn't good. Although I give this movie a 4."
# -->Label=[1]
#
#
# #7837
# I have screened this movie several times here at college, and every time I show it, the number of people watching with me grows exponentially... in addition to the virgins, anyone I've already shown it to NEEDS to see it again! It takes a little while to get into it, but by the end the whole room is screaming, shouting, yelling, rewinding scenes repeatedly, repeating dialogue, and just totally and completely engrossed in the moviegoing experience that is Pia Zadora in \The Lonely Lady\"! Scene after scene after scene of the most ineptly filmed, poorly written, horribly acted TRASH is thrown at you in an all-out assault that ranks as the campiest thing I own (no small statement, friends). For me nothing compares 2 U, Pia... and I don't suppose I'm the only one who's ever felt this way!"
# -->Label=[1]
#
#
# #8724
# There are so many words I want to use to describe this movie, but can't really do that can I? This movie is a movie to watch if you just want to sit, laugh, cry and then pee. I'm serious. Don't watch this movie if you're easily offended by profanity, sex, nudity, homosexuality...and everything else associated with nature. Being a woman, and that might not even be a factor, I can watch this movie over and over again. Trey Parker and Matt Stone are absolutely brilliant. Along with all their other debuts, I think Baseketball is the prize winner. I'm laughing now just thinking about some of the stupid things they do in the movie. Watch the movie!! That's all I'm going to say. It's sort of hard for me to leave this comment because I'm one of those people, like Ozzy Osbourne, who has a curse word in almost every line that blurts out of their mouth when they speak. So I'm keeping it professional. Best movie. Heck yeah!!
# -->Label=[1]
#
#
# #9364
# After viewing several episodes of this series, I have come to the conclusion that television producers are completely devoid of any form of originality. Here is an old science fiction standby, ingeniously wrapped in the form of a truly original concept - and still they can only -almost - make it work.<br /><br />The dialog is good! The male actors are reasonably proficient at their professions. Most of the characters are well drawn, with special kudos to the hero and his more than likeable side-kick. And most of the episode plots come across as palatable. So what could be wrong? How about the, the female characters and the cosmeticly perfect actresses who are chosen to portray them. <br /><br />The producers insist on portraying the female characters in this - almost good - series, in a manner that makes the end product appear to be a misplaced cheerleader. Why, I ask, why?<br /><br />The episodes all fall flat whenever the female guest star or recurring character comes on screen. These actresses are all totally unbelievable in their roles, and you don't actually have to see them to know they are incapable of their acting assignments. A blind person could tell. Just listen to them talk. They deliver their dialog with all the drama and effect of a 16 year old at the high school prom. Who would believe these women are Phd scientist, senators, corporate executives and medical doctors?<br /><br />In a nut shell, if the producers have their choice of a Stockard Channing or a Morgan Fairchild, guess who they'll choose - every time? And of course, the series suffers for it. Too bad!
# -->Label=[1]
#
#
# #10162
# The legendary Boris Karloff ended his illustrious career by making four cheapie fright flick clunkers in Mexico. This is the token moody period Gothic horror entry from the bunch. Karloff gives a typically spry and dignified performance as Matthias Morteval, an elderly eccentric patriarch who invites several of his petty, greedy and backbiting no-count relatives to his creepy rundown castle for the reading of a will. Pretty soon the hateful guests are getting bumped off by lethal life-sized toy people who populate the place. Onetime Mexican sex symbol Andres Garcia of \Tintorera\" infamy portrays the dashing police officer hero and Julissa looks absolutely ravishing as the sole likable female character. The clunky, plodding (non)direction, trite by-the-numbers script, ugly, washed-out cinematography, ridiculous murder set pieces (a gross fat slob gets blasted right in the face by a miniature cannon!), overwrought string score, morbid gloom-doom atmosphere, largely lousy acting (Karloff notably excepted), cheesy mild gore, poor dubbing and rousing fiery conclusion all lend this enjoyably awful lemon a certain endearingly cruddy and hence oddly amusing ratty charm. A real campy hoot."
# -->Label=[1]
#
#
# #10477
# I'm a fan of C&C, going back to their records, and liked this movie, but at one point in the mid-1980's on cable television in San Jose California, it was aired with an alternate plot line that destroyed the entire point of the movie. All references to marijuana were replaced with \diamonds\". The bag that \"Red\" drops to Chong has diamonds in it instead of marijuana, but the conversation still remains the same (\"...it's worth ~$3000/lb\"). There is also a subplot in which clips of aliens on a ship were added observing C&C, and talking to each other about getting the diamonds. At the end, instead of \"space coke\", it's something else. I'm not sure who created this version, but it was horrible, and obvious that they were attempting to make it family/child friendly. It would have been better if that network had not aired it at all."
# -->Label=[1]
#
#
# #12243
# This is simply the funniest movie I've seen in a long time. The bad acting, bad script, bad scenery, bad costumes, bad camera work and bad special effects are so stupid that you find yourself reeling with laughter.<br /><br />So it's not gonna win an Oscar but if you've got beer and friends round then you can't go wrong.
# -->Label=[1]
#
#
# #14445
# I would give this show a ten out of ten if it was not for the fart jokes. You people are so damn sensitive it is inane! So quick to point out the \racism\" of the show and the jokes, yet are also so quick to say ridiculously sexist, pig-headed crap like \"well, duh, some of these other shows do these jokes so much better because at least they have hot women.\" So disgusting. Abortion jokes are great because, really, who takes abortion seriously anyways? At least I'm not a*bore*son. I hear that Reba McEntire and Sarah Silverman are teaming up to do a movie about sisters taking a road trip together. Talk about a movie of the year!"
# -->Label=[1]
#
#
# #15076
# According to this board, I guess either you love it or hate it. Usually how it goes with all movies. There is no need to get testy with others though. All we are doing here is giving opinions. I rented this movie last night and I want to come and throw my opinion in the mix. I was surprised by how many people are thrashing it though. There's a difference between a movie fan and a horror movie fan. I'm a horror movie fan. Most plain olé' movie fans don't like horror movies. So many low budget cam corder looking movies are coming out these days. It's hard to keep up. And what makes it tough to stay into these movies is how bad they are. I wanted to come and write a review about \Hood of the Living Dead\" because it's pretty damn good compared to the rest of the junk out there. It's nothing special but it's those horror film makers that try to be too serious that end up making a horrible horror film. I really liked this one. You telling me there is no effort in this one? And one more thing, I bet all of you have all of these huge DVD collections that you are so proud of, nothing but Major Motion Pictures right? Nothing wrong with that, but you have to know how to appreciate low-budget independent. I knew what I was getting when I watched this movie. I'm not going to be upset because I thought it was going to be some 100 million dollar movie. Some of you might need to stick with watching the Matrix over and over again and stop trying to compare everything to the Matrix. And if most of you are under 24, that explains everything. Good movie folks, check it out."
# -->Label=[1]
#
#
# #18896
# The only reason I wanted to see this was because of Orlando Bloom. Simply put, the movie was spectacularly average. It's not bad, but it's really not very good. The editing is good; the film is well-paced. The direction is competent and assured. The story is plodding. The film is averagely acted by Ledger, Bloom, and the normally great Watts and Rush. The accents are impenetrable if you're from the US so just sit back and enjoy the scenery (or as I like to call it, Orlando Bloom). By the end of the film, I was neither bored nor moved. Some people have asked what happened to Ned Kelly at the end of the movie. I have to say, I so did not care by that point.<br /><br />Really, the only reason I can recommend this is that Orlando Bloom kind of, sort of shows some hints of range (although the oft-present \I'm pretty and confused\" look is prominent), so fangirls may find it worth the matinee price. Other than that, just don't see it. It's neither good enough nor bad enough to be entertaining."
# -->Label=[1]
#
#
# #19741
# I love horses and admire hand drawn animation, so I expected nothing short of amazement from Dreamworks new animated picture Spirit: Stallion of the Cimarron. I guess you could say I was a little bit disappointed. You have wonderful animation and at first what seems like a perfect story. A story about absolutely nothing but a horse in nature. The animals don't sing cute songs or even talk -- a major plus. Sadly, the film has an uncalled for narration by Matt Damon; a sappy soundtrack by Bryan Adams; and enough action scenes to compare it to a Jerry Bruckheimer production. If the film makers would have just stayed with simplicity, we'd have a masterpiece here. This is not a great film, but it is good entertainment for small children. I would recommend this film to families because it has its heart in the right place and its the only thing out there right now that isn't offensive to small children. Not bad, but could have been much better. Very pretty visuals though.
# -->Label=[1]
#
#
# #19895
# For anyone who may not know what a one-actor movie was like, this is the best example. This plot is ridiculous, and really makes no sense. It's full of cliched situations, hackneyed lines, melodrama, comedy... you name it!<br /><br />But Amitabh Bachchan can make anything convincing, and this movie is by no means an exception. Everyone turns in a decent performance - Shashi Kapoor, Waheeda Rehman, Ranjit, Om Prakash, Smita Patil... But it is the Megastar who overshadows everyone with his towering presence. Without him, this movie would have been a non-starter... The story is about separation / mistaken identities / misunderstandings / love / hate / loyalty / good vs evil - everything, really! Amitabh's is a brilliant performance on all counts, in an otherwise silly film! And did I mention that it is ridiculously funny?
# -->Label=[1]

# %%
max_l = 0
min_l = 10000
i = 0
m = -1
for review in reviews_pp_ints:
    if len(review) > max_l:
        max_l = len(review)
    if len(review) < min_l:
        min_l = len(review)
        m = i
    i += 1
reviews[m], m, labels[m]
# Out:
# ('Ming The Merciless does a little Bardwork and a movie most foul!',
#  22258,
#  [0])

# %%
words_count['terrible']
# Out:
# 1005

# %%
words_count['horror']
# Out:
# 2715

# %%
a = [92, 282, 1184, 2331, 2815, 2848, 3233, 4833, 7077, 7713, 7837, 8724, 9364, 10162, 10477, 12243, 14445, 15076, 18896, 19741, 19895]
len(a)
# Out:
# 21
